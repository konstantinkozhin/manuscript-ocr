# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Этот ноутбук демонстрирует базовый запуск обучения корректора `CharLM` в версии `0.1.10`. В примере показано, как использовать встроенные средства библиотеки `manuscript-ocr` для обучения собственной модели коррекции OCR-ошибок на пользовательских данных.
#
# Для обучения корректора в примере используются:
#
# - `words_path` — список слов;
# - `text_path` — текстовый корпус;
# - `pairs_path` — пары ошибочного и корректного написания;
# - `charset_path` — файл допустимого набора символов.
#
# Подробная информация о формате входных данных и параметрах обучения приведена в полной документации проекта: https://konstantinkozhin.github.io/manuscript-ocr/0.1.10/en/api/correctors.html

# %% [markdown]
# ## 1. Установка зависимостей

# %% [markdown]
# Для загрузки примерных данных в данном ноутбуке дополнительно используется библиотека `huggingface_hub`.
#
# Она не является частью библиотеки `manuscript-ocr`, не входит в обязательный набор зависимостей проекта и используется только для автоматического скачивания файлов датасета в рамках данного примера.

# %%
# !pip install manuscript-ocr[dev]==0.1.10
# Out:
# Collecting manuscript-ocr==0.1.10 (from manuscript-ocr[dev]==0.1.10)
#   Downloading manuscript_ocr-0.1.10-py3-none-any.whl.metadata (6.9 kB)
# Collecting onnxruntime>=1.16 (from manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10)
#   Downloading onnxruntime-1.24.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (2.0.2)
# Requirement already satisfied: opencv-python>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (4.13.0.92)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (11.3.0)
# Requirement already satisfied: shapely>=1.8 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (2.1.2)
# Requirement already satisfied: scikit-image>=0.19 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (0.25.2)
# Requirement already satisfied: numba>=0.56 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (0.60.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (2.12.3)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (4.67.3)
# Requirement already satisfied: gdown>=4.4 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (5.2.1)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr[dev]==0.1.10) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.14 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr[dev]==0.1.10) (0.25.0+cu128)
# Collecting onnx>=1.12 (from manuscript-ocr[dev]==0.1.10)
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Collecting onnxsim>=0.4 (from manuscript-ocr[dev]==0.1.10)
#   Downloading onnxsim-0.6.2-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting torch-optimizer>=0.1 (from manuscript-ocr[dev]==0.1.10)
#   Downloading torch_optimizer-0.3.0-py3-none-any.whl.metadata (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 2.9 MB/s eta 0:00:00
# Collecting evaluate>=0.4 (from manuscript-ocr[dev]==0.1.10)
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Collecting jiwer>=2.2 (from manuscript-ocr[dev]==0.1.10)
#   Downloading jiwer-4.0.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr[dev]==0.1.10) (3.10.0)
# Requirement already satisfied: albumentations>=1.0 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr[dev]==0.1.10) (2.0.8)
# Requirement already satisfied: tensorboard>=2.4 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr[dev]==0.1.10) (2.19.0)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr[dev]==0.1.10) (2.2.2)
# Requirement already satisfied: pytest>=7 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr[dev]==0.1.10) (8.4.2)
# Collecting pytest-cov>=4 (from manuscript-ocr[dev]==0.1.10)
#   Downloading pytest_cov-7.1.0-py3-none-any.whl.metadata (32 kB)
# Collecting black>=22 (from manuscript-ocr[dev]==0.1.10)
#   Downloading black-26.3.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 kB 6.6 MB/s eta 0:00:00
# Collecting flake8>=5 (from manuscript-ocr[dev]==0.1.10)
#   Downloading flake8-7.3.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting isort>=5.10 (from manuscript-ocr[dev]==0.1.10)
#   Downloading isort-8.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting mypy>=0.991 (from manuscript-ocr[dev]==0.1.10)
#   Downloading mypy-1.20.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: sphinx>=5 in /usr/local/lib/python3.12/dist-packages (from manuscript-ocr[dev]==0.1.10) (8.2.3)
# Collecting sphinx-rtd-theme>=1 (from manuscript-ocr[dev]==0.1.10)
#   Downloading sphinx_rtd_theme-3.1.0-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting numpydoc>=1.5 (from manuscript-ocr[dev]==0.1.10)
#   Downloading numpydoc-1.10.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting sphinx-autodoc-typehints>=1.24 (from manuscript-ocr[dev]==0.1.10)
#   Downloading sphinx_autodoc_typehints-3.10.0-py3-none-any.whl.metadata (19 kB)
# Collecting sphinxcontrib-mermaid>=0.9 (from manuscript-ocr[dev]==0.1.10)
#   Downloading sphinxcontrib_mermaid-2.0.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting build>=0.8 (from manuscript-ocr[dev]==0.1.10)
#   Downloading build-1.4.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting twine>=4 (from manuscript-ocr[dev]==0.1.10)
#   Downloading twine-6.2.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations>=1.0->manuscript-ocr[dev]==0.1.10) (1.16.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from albumentations>=1.0->manuscript-ocr[dev]==0.1.10) (6.0.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations>=1.0->manuscript-ocr[dev]==0.1.10) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations>=1.0->manuscript-ocr[dev]==0.1.10) (4.13.0.92)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations>=1.0->manuscript-ocr[dev]==0.1.10) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations>=1.0->manuscript-ocr[dev]==0.1.10) (6.5.16)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from black>=22->manuscript-ocr[dev]==0.1.10) (8.3.1)
# Collecting mypy-extensions>=0.4.3 (from black>=22->manuscript-ocr[dev]==0.1.10)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.12/dist-packages (from black>=22->manuscript-ocr[dev]==0.1.10) (26.0)
# Collecting pathspec>=1.0.0 (from black>=22->manuscript-ocr[dev]==0.1.10)
#   Downloading pathspec-1.0.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.12/dist-packages (from black>=22->manuscript-ocr[dev]==0.1.10) (4.9.4)
# Collecting pytokens~=0.4.0 (from black>=22->manuscript-ocr[dev]==0.1.10)
#   Downloading pytokens-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting pyproject_hooks (from build>=0.8->manuscript-ocr[dev]==0.1.10)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (4.0.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (0.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (1.8.0)
# Collecting mccabe<0.8.0,>=0.7.0 (from flake8>=5->manuscript-ocr[dev]==0.1.10)
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting pycodestyle<2.15.0,>=2.14.0 (from flake8>=5->manuscript-ocr[dev]==0.1.10)
#   Downloading pycodestyle-2.14.0-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting pyflakes<3.5.0,>=3.4.0 (from flake8>=5->manuscript-ocr[dev]==0.1.10)
#   Downloading pyflakes-3.4.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown>=4.4->manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown>=4.4->manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (3.25.2)
# Collecting rapidfuzz>=3.9.7 (from jiwer>=2.2->manuscript-ocr[dev]==0.1.10)
#   Downloading rapidfuzz-3.14.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->manuscript-ocr[dev]==0.1.10) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->manuscript-ocr[dev]==0.1.10) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->manuscript-ocr[dev]==0.1.10) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->manuscript-ocr[dev]==0.1.10) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->manuscript-ocr[dev]==0.1.10) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->manuscript-ocr[dev]==0.1.10) (2.9.0.post0)
# Requirement already satisfied: typing_extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from mypy>=0.991->manuscript-ocr[dev]==0.1.10) (4.15.0)
# Collecting librt>=0.8.0 (from mypy>=0.991->manuscript-ocr[dev]==0.1.10)
#   Downloading librt-0.9.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.56->manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (0.43.0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.12->manuscript-ocr[dev]==0.1.10) (5.29.6)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.12->manuscript-ocr[dev]==0.1.10) (0.5.4)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.16->manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (25.12.19)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.16->manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (1.14.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from onnxsim>=0.4->manuscript-ocr[dev]==0.1.10) (13.9.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->manuscript-ocr[dev]==0.1.10) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->manuscript-ocr[dev]==0.1.10) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (0.4.2)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=7->manuscript-ocr[dev]==0.1.10) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=7->manuscript-ocr[dev]==0.1.10) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=7->manuscript-ocr[dev]==0.1.10) (2.20.0)
# Collecting coverage>=7.10.6 (from coverage[toml]>=7.10.6->pytest-cov>=4->manuscript-ocr[dev]==0.1.10)
#   Downloading coverage-7.13.5-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.19->manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.19->manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.19->manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (2026.3.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.19->manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (0.5)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5->manuscript-ocr[dev]==0.1.10) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5->manuscript-ocr[dev]==0.1.10) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5->manuscript-ocr[dev]==0.1.10) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5->manuscript-ocr[dev]==0.1.10) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5->manuscript-ocr[dev]==0.1.10) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5->manuscript-ocr[dev]==0.1.10) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5->manuscript-ocr[dev]==0.1.10) (3.1.6)
# Requirement already satisfied: docutils<0.22,>=0.20 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5->manuscript-ocr[dev]==0.1.10) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5->manuscript-ocr[dev]==0.1.10) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5->manuscript-ocr[dev]==0.1.10) (2.18.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5->manuscript-ocr[dev]==0.1.10) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5->manuscript-ocr[dev]==0.1.10) (2.0.0)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5->manuscript-ocr[dev]==0.1.10) (4.1.0)
# Collecting sphinx>=5 (from manuscript-ocr[dev]==0.1.10)
#   Downloading sphinx-9.1.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: roman-numerals>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5->manuscript-ocr[dev]==0.1.10) (4.1.0)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme>=1->manuscript-ocr[dev]==0.1.10)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.4->manuscript-ocr[dev]==0.1.10) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.4->manuscript-ocr[dev]==0.1.10) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.4->manuscript-ocr[dev]==0.1.10) (3.10.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.4->manuscript-ocr[dev]==0.1.10) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.4->manuscript-ocr[dev]==0.1.10) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.4->manuscript-ocr[dev]==0.1.10) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.4->manuscript-ocr[dev]==0.1.10) (3.1.7)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->manuscript-ocr[dev]==0.1.10) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.13->manuscript-ocr[dev]==0.1.10) (1.5.0)
# Collecting pytorch-ranger>=0.1.1 (from torch-optimizer>=0.1->manuscript-ocr[dev]==0.1.10)
#   Downloading pytorch_ranger-0.1.1-py3-none-any.whl.metadata (509 bytes)
# Collecting readme-renderer>=35.0 (from twine>=4->manuscript-ocr[dev]==0.1.10)
#   Downloading readme_renderer-44.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from twine>=4->manuscript-ocr[dev]==0.1.10) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from twine>=4->manuscript-ocr[dev]==0.1.10) (2.5.0)
# Requirement already satisfied: keyring>=21.2.0 in /usr/local/lib/python3.12/dist-packages (from twine>=4->manuscript-ocr[dev]==0.1.10) (25.7.0)
# Collecting rfc3986>=1.4.0 (from twine>=4->manuscript-ocr[dev]==0.1.10)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting id (from twine>=4->manuscript-ocr[dev]==0.1.10)
#   Downloading id-1.6.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (18.1.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (3.13.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (0.24.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2>=3.1->sphinx>=5->manuscript-ocr[dev]==0.1.10) (3.0.3)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=21.2.0->twine>=4->manuscript-ocr[dev]==0.1.10) (3.5.0)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=21.2.0->twine>=4->manuscript-ocr[dev]==0.1.10) (0.9.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.12/dist-packages (from keyring>=21.2.0->twine>=4->manuscript-ocr[dev]==0.1.10) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from keyring>=21.2.0->twine>=4->manuscript-ocr[dev]==0.1.10) (4.4.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.12/dist-packages (from keyring>=21.2.0->twine>=4->manuscript-ocr[dev]==0.1.10) (6.1.2)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine>=4->manuscript-ocr[dev]==0.1.10)
#   Downloading nh3-0.3.4-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->onnxsim>=0.4->manuscript-ocr[dev]==0.1.10) (4.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.16->manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown>=4.4->manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (2.8.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown>=4.4->manuscript-ocr==0.1.10->manuscript-ocr[dev]==0.1.10) (1.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (1.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->onnxsim>=0.4->manuscript-ocr[dev]==0.1.10) (0.1.2)
# Requirement already satisfied: cryptography>=2.0 in /usr/local/lib/python3.12/dist-packages (from SecretStorage>=3.2->keyring>=21.2.0->twine>=4->manuscript-ocr[dev]==0.1.10) (43.0.3)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from jaraco.classes->keyring>=21.2.0->twine>=4->manuscript-ocr[dev]==0.1.10) (10.8.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.7.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.7.0->evaluate>=0.4->manuscript-ocr[dev]==0.1.10) (0.0.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=21.2.0->twine>=4->manuscript-ocr[dev]==0.1.10) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=21.2.0->twine>=4->manuscript-ocr[dev]==0.1.10) (3.0)
# Downloading manuscript_ocr-0.1.10-py3-none-any.whl (959 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.8/959.8 kB 34.8 MB/s eta 0:00:00
# Downloading black-26.3.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 83.5 MB/s eta 0:00:00
# Downloading build-1.4.2-py3-none-any.whl (24 kB)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.0 MB/s eta 0:00:00
# Downloading flake8-7.3.0-py2.py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 5.8 MB/s eta 0:00:00
# Downloading isort-8.0.1-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 11.6 MB/s eta 0:00:00
# Downloading jiwer-4.0.0-py3-none-any.whl (23 kB)
# Downloading mypy-1.20.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 99.6 MB/s eta 0:00:00
# Downloading numpydoc-1.10.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.3/69.3 kB 7.8 MB/s eta 0:00:00
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 93.2 MB/s eta 0:00:00
# Downloading onnxruntime-1.24.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 92.1 MB/s eta 0:00:00
# Downloading onnxsim-0.6.2-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 98.5 MB/s eta 0:00:00
# Downloading pytest_cov-7.1.0-py3-none-any.whl (22 kB)
# Downloading sphinx_autodoc_typehints-3.10.0-py3-none-any.whl (38 kB)
# Downloading sphinx-9.1.0-py3-none-any.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 45.2 MB/s eta 0:00:00
# Downloading sphinx_rtd_theme-3.1.0-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 125.1 MB/s eta 0:00:00
# Downloading sphinxcontrib_mermaid-2.0.1-py3-none-any.whl (14 kB)
# Downloading torch_optimizer-0.3.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 6.9 MB/s eta 0:00:00
# Downloading twine-6.2.0-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 4.5 MB/s eta 0:00:00
# Downloading coverage-7.13.5-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.2/254.2 kB 27.6 MB/s eta 0:00:00
# Downloading librt-0.9.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (230 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.3/230.3 kB 22.9 MB/s eta 0:00:00
# Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pathspec-1.0.4-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 6.5 MB/s eta 0:00:00
# Downloading pycodestyle-2.14.0-py2.py3-none-any.whl (31 kB)
# Downloading pyflakes-3.4.0-py2.py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 6.7 MB/s eta 0:00:00
# Downloading pytokens-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (269 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.8/269.8 kB 30.3 MB/s eta 0:00:00
# Downloading pytorch_ranger-0.1.1-py3-none-any.whl (14 kB)
# Downloading rapidfuzz-3.14.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 94.3 MB/s eta 0:00:00
# Downloading readme_renderer-44.0-py3-none-any.whl (13 kB)
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 14.8 MB/s eta 0:00:00
# Downloading id-1.6.1-py3-none-any.whl (14 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading nh3-0.3.4-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (804 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.0/805.0 kB 65.1 MB/s eta 0:00:00
# Installing collected packages: rfc3986, rapidfuzz, pytokens, pyproject_hooks, pyflakes, pycodestyle, pathspec, nh3, mypy-extensions, mccabe, librt, isort, id, coverage, sphinx, readme-renderer, onnxruntime, onnx, mypy, jiwer, flake8, build, black, sphinxcontrib-mermaid, sphinxcontrib-jquery, sphinx-autodoc-typehints, pytest-cov, onnxsim, numpydoc, sphinx-rtd-theme, pytorch-ranger, manuscript-ocr, twine, torch-optimizer, evaluate
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 8.2.3
#     Uninstalling Sphinx-8.2.3:
#       Successfully uninstalled Sphinx-8.2.3
# Successfully installed black-26.3.1 build-1.4.2 coverage-7.13.5 evaluate-0.4.6 flake8-7.3.0 id-1.6.1 isort-8.0.1 jiwer-4.0.0 librt-0.9.0 manuscript-ocr-0.1.10 mccabe-0.7.0 mypy-1.20.0 mypy-extensions-1.1.0 nh3-0.3.4 numpydoc-1.10.0 onnx-1.21.0 onnxruntime-1.24.4 onnxsim-0.6.2 pathspec-1.0.4 pycodestyle-2.14.0 pyflakes-3.4.0 pyproject_hooks-1.2.0 pytest-cov-7.1.0 pytokens-0.4.1 pytorch-ranger-0.1.1 rapidfuzz-3.14.5 readme-renderer-44.0 rfc3986-2.0.0 sphinx-9.1.0 sphinx-autodoc-typehints-3.10.0 sphinx-rtd-theme-3.1.0 sphinxcontrib-jquery-4.1 sphinxcontrib-mermaid-2.0.1 torch-optimizer-0.3.0 twine-6.2.0

# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.8.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub) (0.1.2)

# %% [markdown]
# ## 2. Скачивание данных

# %%
from pathlib import Path
from huggingface_hub import hf_hub_download


repo_id = "anna4uonline/TextCorrectorDataset"
local_dir = Path("datasets") / "TextCorrectorDataset" / "prereform_russian_data"
local_dir.mkdir(parents=True, exist_ok=True)

files = [
    "prereform_russian_data/charset.txt",
    "prereform_russian_data/pred_StackMix-YeniseiGovReports.csv",
    "prereform_russian_data/prereform_texts.txt",
    "prereform_russian_data/prereform_words.txt",
]

downloaded = {}
for file in files:
    path = hf_hub_download(
        repo_id=repo_id,
        repo_type="dataset",
        filename=file,
        local_dir=local_dir.parent,
        local_dir_use_symlinks=False,
    )
    downloaded[Path(file).name] = str(Path(path).resolve())

charset_path = downloaded["charset.txt"]
pairs_path = downloaded["pred_StackMix-YeniseiGovReports.csv"]
text_path = downloaded["prereform_texts.txt"]
words_path = downloaded["prereform_words.txt"]

print("charset_path =", charset_path)
print("pairs_path   =", pairs_path)
print("text_path    =", text_path)
print("words_path   =", words_path)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:206: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# charset.txt:   0%|          | 0.00/694 [00:00<?, ?B/s]
# prereform_russian_data/pred_StackMix-Yen(…):   0%|          | 0.00/89.8M [00:00<?, ?B/s]
# prereform_russian_data/prereform_texts.t(…):   0%|          | 0.00/70.9M [00:00<?, ?B/s]
# prereform_russian_data/prereform_words.t(…):   0%|          | 0.00/36.3M [00:00<?, ?B/s]
# charset_path = /content/datasets/TextCorrectorDataset/prereform_russian_data/charset.txt
# pairs_path   = /content/datasets/TextCorrectorDataset/prereform_russian_data/pred_StackMix-YeniseiGovReports.csv
# text_path    = /content/datasets/TextCorrectorDataset/prereform_russian_data/prereform_texts.txt
# words_path   = /content/datasets/TextCorrectorDataset/prereform_russian_data/prereform_words.txt

# %% [markdown]
# ## 3. Запуск обучения

# %% [markdown]
# В версии `0.1.10` для запуска данного примера может потребоваться дополнительная установка библиотеки `Levenshtein`. Начиная с версии 0.1.12, данная проблема исправлена, и библиотека Levenshtein входит в состав зависимостей проекта.

# %%
# !pip install Levenshtein
# Out:
# Collecting Levenshtein
#   Downloading levenshtein-0.27.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from Levenshtein) (3.14.5)
# Downloading levenshtein-0.27.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.3/153.3 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: Levenshtein
# Successfully installed Levenshtein-0.27.3

# %%
from manuscript.correctors import CharLM

CharLM.train(
    words_path=words_path,
    text_path=text_path,
    pairs_path=pairs_path,
    charset_path=charset_path,
    epochs=1,
)
# Out:
# Device: cuda
# Words: 1,500,000
# Train pairs: 283646, Eval pairs: 2865
# Building substitutions dictionary...
# Substitutions: 1090, saved to exp_charlm/substitutions.json
#   л→м: 11652
#   ъ→ѣ: 7160
#   о→а: 6041
#   ь→я: 5778
#   ь→ъ: 5728
#   п→т: 4815
#   е→ѣ: 4293
#   й→я: 3954
#   п→н: 3850
#   ы→ь: 3811
# NgramDataset: /content/datasets/TextCorrectorDataset/prereform_russian_data/prereform_texts.txt
# PairsDataset: 283646 pairs
# MixedDataset: pairs_ratio=0.80 (80% OCR)
# /usr/local/lib/python3.12/dist-packages/manuscript/correctors/_charlm/model.py:16: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=n_layers)
# /usr/local/lib/python3.12/dist-packages/manuscript/correctors/_charlm/train.py:177: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if cfg.get("use_amp", False) and device == "cuda" else None
# Using mixed precision (AMP)
# Epoch 1:   0%|          | 0/5860 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/manuscript/correctors/_charlm/train.py:210: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch 1: 100%|██████████| 5860/5860 [05:47<00:00, 16.86it/s, acc=62.3%, loss=0.618]
# [Epoch 1] loss=0.8283 acc=49.70%
# ---- MLM examples ----
# INPUT   : <MASK>осова
# TARGET  : Носова
# PREDICT : носова
#
# INPUT   : закр<MASK>пощать
# TARGET  : закрѣпощать
# PREDICT : закрѣпощать
#
# INPUT   : дн<MASK><MASK>тъ
# TARGET  : днюетъ
# PREDICT : дняетъ
# Confidence: correct={'n': 27153, 'mean': 0.4738413469625812, 'p25': 0.09235525131225586, 'median': 0.4171375632286072, 'p75': 0.8855694532394409}, incorrect={'n': 4074, 'mean': 0.10472154712385892, 'p25': 0.0011705424403771758, 'median': 0.013855399563908577, 'p75': 0.09317850321531296}
# exact_match: 0.1592
# cer_before: 0.1406
# cer_after: 0.1262
# delta: -0.0144
# improved_pct: 17.0332
# worsened_pct: 0.8377
# unchanged_pct: 82.1291
# 'exp_charlm/checkpoints/charlm_epoch_1.pt'

# %% [markdown]
# ## 4. Экспорт модели в формат для инференса

# %% [markdown]
# Для экспорта модели в данном примере дополнительно требуется установка библиотеки `onnxscript`. В более поздних версиях библиотеки эта проблема устранена

# %%
# !pip install onnxscript
# Out:
# Collecting onnxscript
#   Downloading onnxscript-0.6.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.12/dist-packages (from onnxscript) (0.5.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from onnxscript) (2.0.2)
# Collecting onnx_ir<2,>=0.1.15 (from onnxscript)
#   Downloading onnx_ir-0.2.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: onnx>=1.17 in /usr/local/lib/python3.12/dist-packages (from onnxscript) (1.21.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxscript) (26.0)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from onnxscript) (4.15.0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.17->onnxscript) (5.29.6)
# Requirement already satisfied: sympy>=1.13 in /usr/local/lib/python3.12/dist-packages (from onnx_ir<2,>=0.1.15->onnxscript) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13->onnx_ir<2,>=0.1.15->onnxscript) (1.3.0)
# Downloading onnxscript-0.6.2-py3-none-any.whl (689 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 689.1/689.1 kB 18.8 MB/s eta 0:00:00
# Downloading onnx_ir-0.2.0-py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 kB 19.1 MB/s eta 0:00:00
# Installing collected packages: onnx_ir, onnxscript
# Successfully installed onnx_ir-0.2.0 onnxscript-0.6.2

# %%
from pathlib import Path

from manuscript.correctors import CharLM

exp_dir = Path("exp_charlm")

CharLM.export(
    weights_path=str(exp_dir / "checkpoints" / "charlm_epoch_1.pt"),
    vocab_path=str(exp_dir / "vocab.json"),
    output_path=str(exp_dir / "exported_charlm.pt"),
)
# Out:
# Loading vocab from exp_charlm/vocab.json...
# Vocab size: 92
# Loading checkpoint from exp_charlm/checkpoints/charlm_epoch_1.pt...
#
# === CharLM ONNX Export ===
# Max length: 32
# Embedding size: 192
# Layers: 8
# Heads: 6
#
# Exporting to ONNX...
# /usr/local/lib/python3.12/dist-packages/manuscript/correctors/_charlm/__init__.py:659: UserWarning: # 'dynamic_axes' is not recommended when dynamo=True, and may lead to 'torch._dynamo.exc.UserError: Constraints violated.' Supply the 'dynamic_shapes' argument instead if export is unsuccessful.
#   torch.onnx.export(
# W0410 10:01:50.591000 3036 torch/onnx/_internal/exporter/_compat.py:125] Setting ONNX exporter to use operator set version 18 because the requested opset_version 14 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# W0410 10:01:51.346000 3036 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0, sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0410 10:01:51.347000 3036 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0, sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0410 10:01:51.351000 3036 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# W0410 10:01:51.354000 3036 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# [torch.onnx] Obtain model graph for `CharTransformerMLM([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `CharTransformerMLM([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# /usr/lib/python3.12/copyreg.py:99: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return cls.__new__(cls, *args)
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# WARNING:onnxscript.version_converter:The model version conversion is not supported by the onnxscript version converter and fallback is enabled. The model will be converted using the onnx C API (target version: 14).
# WARNING:onnxscript.version_converter:Failed to convert the model to the target version 14 using the ONNX C API. The model was not modified
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/__init__.py", line 120, in call
#     converted_proto = _c_api_utils.call_onnx_api(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/_c_api_utils.py", line 65, in call_onnx_api
#     result = func(proto)
#              ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/__init__.py", line 115, in _partial_convert_version
#     return onnx.version_converter.convert_version(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnx/version_converter.py", line 39, in convert_version
#     converted_model_str = C.convert_version(model_str, target_version)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: /github/workspace/onnx/version_converter/adapters/no_previous_version.h:24: adapt: Assertion `false` failed: No Previous Version of LayerNormalization exists
# [torch.onnx] Translate the graph into ONNX... ✅
# Applied 22 of general pattern rewrite rules.
# [OK] ONNX model saved to: exp_charlm/exported_charlm.pt
# Simplifying ONNX model...
# [OK] Model simplified successfully
#
# Export complete: exp_charlm/exported_charlm.pt
