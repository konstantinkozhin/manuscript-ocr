# %% [markdown]
# Данные доступны по ссылке: https://huggingface.co/datasets/anna4uonline/YeniseiGovReports-TD

# %%
from manuscript.detectors import EAST


train_images = r"C:\shared\Archives020525\test_images" # Используется валидационнный набор для быстрого теста
train_annotations = r"C:\shared\Archives020525\test.json" # Используется валидационнный набор для быстрого теста
val_images = r"C:\shared\Archives020525\test_images"
val_annotations = r"C:\shared\Archives020525\test.json"

EAST.train(train_images=train_images,
           train_anns=train_annotations,
           val_images=val_images,
           val_anns=val_annotations,
           epochs=1,
           batch_size=1,)
# Out:
# Training configuration saved to: c:\Users\pasha\manuscript-ocr\notebooks\experiments\resnet_quad\training_config.json
# C:\Users\pasha\manuscript-ocr\src\manuscript\detectors\_east\train_utils.py:249: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# Train 1: 100%|██████████| 270/270 [01:47<00:00,  2.52it/s]
# Attempting to export best model to ONNX...
# Failed to export ONNX model: type object 'EAST' has no attribute 'export_to_onnx'
# EASTModel(
#   (backbone): ResNetFeatureExtractor(
#     (extractor): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Module(
# ...

# %%
EAST.export(weights_path=r"C:\Users\pasha\manuscript-ocr\notebooks\experiments\resnet_quad\checkpoints\best.pth",
            output_path=r"C:\Users\pasha\manuscript-ocr\notebooks\experiments\resnet_quad\exported_model.pth")
# Out:
# Loading checkpoint from C:\Users\pasha\manuscript-ocr\notebooks\experiments\resnet_quad\checkpoints\best.pth...
# Auto-detecting backbone architecture...
#    Detected 114 layer3 parameters
#    Auto-detected backbone: resnet50
#
# Loading PyTorch model...
# ...
